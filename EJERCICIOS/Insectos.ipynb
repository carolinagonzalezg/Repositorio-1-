# %% [markdown]
# <a href="https://colab.research.google.com/github/carolinagonzalezg/Repositorio-1-/blob/main/EJERCICIOS/Insectos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importar el modelo de interes
#import tensorflow as tf
from tensorflow.keras.applications.efficientnet import EfficientNetB0 
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.efficientnet import preprocess_input, decode_predictions
import numpy as np

# %%
model = EfficientNetB0(weights='imagenet')
# Out:
# ...
# 21834768/21834768 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 224, 224, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 224, 224, 3)  7           ['rescaling[0][0]']
#
#  rescaling_1 (Rescaling)        (None, 224, 224, 3)  0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 225, 225, 3)  0           ['rescaling_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 112, 112, 32  864         ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 112, 112, 32  128         ['stem_conv[0][0]']
#                                 )
#
# ...

# %%
img_path = '/content/drive/MyDrive/IC/mosca-domestica-900_1.jpg'

# %%
img = image.load_img(img_path, target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F2A085C6E80>

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
x = image.img_to_array(img)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x.shape
# Out:
# (224, 224, 3)

# %%
x = np.expand_dims(x, axis=0)

# %%
x.shape
# Out:
# (1, 224, 224, 3)

# %%
x = preprocess_input(x)

# %%
preds = model.predict(x)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
preds.shape
# Out:
# (1, 1000)

# %%
np.argmax(preds, axis=1)
# Out:
# array([308])

# %%
print('Predicted:', decode_predictions(preds, top=5)[0])
# Out:
# ...
# 35363/35363 [==============================] - 0s 0us/step
# Predicted: [('n02190166', 'fly', 0.97737646), ('n02206856', 'bee', 0.0013047204), ('n02268443', 'dragonfly', 0.00019289277), ('n02167151', 'ground_beetle', 0.00019200446), ('n11879895', 'rapeseed', 0.00014527798)]

# %%
img_path = '/content/drive/MyDrive/IC/catarina_72_600.jpg'

# %%
img = image.load_img(img_path, target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F29FAF930D0>

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
x = image.img_to_array(img)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x.shape
# Out:
# (224, 224, 3)

# %%
x = np.expand_dims(x, axis=0)

# %%
x.shape
# Out:
# (1, 224, 224, 3)

# %%
x = preprocess_input(x)

# %%
preds = model.predict(x)
# Out:
# 1/1 [==============================] - 0s 116ms/step

# %%
preds.shape
# Out:
# (1, 1000)

# %%
np.argmax(preds, axis=1)
# Out:
# array([301])

# %%
print('Predicted:', decode_predictions(preds, top=5)[0])
# Out:
# Predicted: [('n02165456', 'ladybug', 0.7273788), ('n02169497', 'leaf_beetle', 0.09954855), ('n01776313', 'tick', 0.0025208849), ('n02177972', 'weevil', 0.0020734326), ('n02259212', 'leafhopper', 0.0019208972)]

# %%
img_path = '/content/drive/MyDrive/IC/360_F_128667911_W1zgc2tccUWRN4x9AMKdmLvPxRZ06BkS.jpg'

# %%
img = image.load_img(img_path, target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F29FAD9BB20>

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
x = image.img_to_array(img)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x.shape
# Out:
# (224, 224, 3)

# %%
x = np.expand_dims(x, axis=0)

# %%
x.shape
# Out:
# (1, 224, 224, 3)

# %%
x = preprocess_input(x)

# %%
preds = model.predict(x)
# Out:
# 1/1 [==============================] - 0s 224ms/step

# %%
preds.shape
# Out:
# (1, 1000)

# %%
np.argmax(preds, axis=1)
# Out:
# array([315])

# %%
print('Predicted:', decode_predictions(preds, top=5)[0])
# Out:
# Predicted: [('n02236044', 'mantis', 0.78217345), ('n02226429', 'grasshopper', 0.012689409), ('n02259212', 'leafhopper', 0.011634661), ('n02231487', 'walking_stick', 0.011084066), ('n02264363', 'lacewing', 0.009377272)]
