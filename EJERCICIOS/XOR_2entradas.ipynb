# %% [markdown]
# <a href="https://colab.research.google.com/github/carolinagonzalezg/Repositorio-1-/blob/main/EJERCICIOS/XOR_2entradas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Carga de librerías
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense

# %%
#compuerta OR 3 
training_data = np.array([[0,0],[0,1],[1,0],[1,1]],"float32")

# %%
#salidas deseadas
target_data=np.array([[0],[1],[1],[0]],"float32")

# %%
target_data
# Out:
# array([[0.],
#        [1.],
#        [1.],
#        [0.]], dtype=float32)

# %%
model = Sequential()
model.add(Dense(3, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['binary_accuracy'])
model.fit(training_data, target_data, epochs=300)
resultados=model.evaluate(training_data, target_data)
print("\n%s: %.2f%%" % (model.metrics_names[1], resultados[1]*100))
print(model.predict(training_data).round())
# Out:
# Epoch 1/300
# 1/1 [==============================] - 1s 544ms/step - loss: 0.2422 - binary_accuracy: 0.7500
# Epoch 2/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2421 - binary_accuracy: 0.7500
# Epoch 3/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2421 - binary_accuracy: 0.5000
# Epoch 4/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2420 - binary_accuracy: 0.5000
# Epoch 5/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2420 - binary_accuracy: 0.5000
# Epoch 6/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2420 - binary_accuracy: 0.5000
# Epoch 7/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2419 - binary_accuracy: 0.5000
# Epoch 8/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2419 - binary_accuracy: 0.5000
# Epoch 9/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2418 - binary_accuracy: 0.5000
# Epoch 10/300
# ...
